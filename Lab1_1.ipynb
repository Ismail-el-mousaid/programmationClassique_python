# %% [markdown]
# # Lab11:Programmation classique sous Python

# %%
print("salam tt le monde !")
# Out:
# salam tt le monde !

# %% [markdown]
# ### Afficher un nbr aléatoire entre 1 et 6

# %%
from random import randint
print(randint(1,6))
# Out:
# 2

# %% [markdown]
# ### Afficher un nom aléatoire à partir d'une liste

# %%
from random import choice
names = ['Ismail', 'Aguero', 'Jane', 'Jack', 'Jill', 'Jean']
print("The name selected is: ", choice(names))
# Out:
# The name selected is:  Aguero

# %% [markdown]
# ### Afficher une photo aléatoire à partir d'une liste

# %%
from random import choice
from IPython.display import Image, display
photos = ['a', 'b', 'c']
name = choice(photos)
print("Name:", name)
display(Image(filename="images/"+name+".jpg"))
# Out:
# Name: b

# %% [markdown]
# ### Afficher photo puis la supprimer

# %%
from random import choice
from IPython.display import Image, display
photos = ['a', 'b', 'c']
x = ''
while photos and x!='q':
    name = choice(photos)
    print("Name:", name)
    display(Image(filename="images/"+name+".jpg"))
    photos.remove(name)
    x = input("Enter to continue or q to Exit")
print("-----------END----------------")
# Out:
# Name: a

# %% [markdown]
# ### Afficher une photo aléatoire à partir d'un dossier

# %%
from random import choice
from IPython.display import Image, display
import glob
photos = glob.glob("images/*.jpg")
x = ''
while photos and x!='q':
    path = choice(photos)
    name = path.split('/')[1].split('.')[0]
    print("name:", name)
    print("path:", path)
    display(Image(filename=path))
    photos.remove(name)
    x = input("Enter to continue or q to Exit")
print("-----------END----------------")

# %% [markdown]
# ### Jeu Aléatoire

# %%
import random
nb = random.randint(1, 100)
ch = -1
n = 0
while nb != ch:
    ch = int(input("Entrez un nombre"))
    if ch < nb : print("plus petit")
    if ch > nb : print("plus grand")
    n = n+1
print("Bravo vous l'avez trouvé après : ",n, "essais")

# %% [markdown]
# ## Face Recognition

# %%
pip install cmake
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install face-recognition
# Out:
# ...
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# ...
#   Using cached dlib-19.22.1.tar.gz (7.4 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.Building wheels for collected packages: dlib
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\user\anaconda3\python.exe' -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\user\\AppData\\Local\\Temp\\pip-install-gs5p7zjl\\dlib_982e055b4a7e429e8f31d4709b0da671\\setup.py'"'"'; __file__='"'"'C:\\Users\\user\\AppData\\Local\\Temp\\pip-install-gs5p7zjl\\dlib_982e055b4a7e429e8f31d4709b0da671\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\user\AppData\Local\Temp\pip-wheel-2gh88q0p'
#        cwd: C:\Users\user\AppData\Local\Temp\pip-install-gs5p7zjl\dlib_982e055b4a7e429e8f31d4709b0da671\
# ...

# %%
#import Pillow
#import face_recognition

# %%
import PIL.Image
import PIL.ImageDraw
import face_recognition

# %%
#python -m pip install --upgrade pip

# %%
#Nous devons charger notre image dans la méthode load_image_file()
given_image = face_recognition.load_image_file('images/aguero.jpg')

# %%
#compter le nombre de visages dans l'image_donnée et imprimerons la longueur totale des visages trouvés dans l'image.
face_locations = face_recognition.face_locations(given_image)

number_of_faces = len(face_locations)
print("We found {} face(s) in this image.".format(number_of_faces))
# Out:
# We found 1 face(s) in this image.

# %%
#dessiner n'importe quelle forme sur l'image, nous allons convertir l'image en objet de la bibliothèque Pillow en utilisant la méthode fromarray() de PIL.Image
pil_image = PIL.Image.fromarray(given_image)

# %%
#exécuter une boucle for-in pour imprimer quatre emplacements de pixels tels que haut, gauche, bas et droite des visages détectés.
for face_location in face_locations:
    top, left, bottom, right = face_location
    print("A face is detected at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))
# Out:
# A face is detected at pixel location Top: 98, Left: 613, Bottom: 284, Right: 428

# %%
# dessiner une boîte rectangle de couleur verte avec une largeur de 10 autour des faces
draw = PIL.ImageDraw.Draw(pil_image)
draw.rectangle([left, top, right, bottom], outline="green", width=10)

# %%
#afficher notre nouvelle image avec les visages détectés en utilisant une bordure rectangulaire autour d'eux.
pil_image.show()

# %%
import face_recognition
import cv2
import numpy as np

# This is a demo of running face recognition on live video from your webcam. It's a little more complicated than the
# other example, but it includes some basic performance tweaks to make things run a lot faster:
#   1. Process each video frame at 1/4 resolution (though still display it at full resolution)
#   2. Only detect faces in every other frame of video.

# PLEASE NOTE: This example requires OpenCV (the `cv2` library) to be installed only to read from your webcam.
# OpenCV is *not* required to use the face_recognition library. It's only required if you want to run this
# specific demo. If you have trouble installing it, try any of the other demos that don't reqquire it instead.

# Get a reference to webcam #0 (the default one)
video_capture = cv2.VideoCapture(0)

# Load a sample picture and learn how to recognize it.
obama_image = face_recognition.load_image_file("images\\photo.jpg")
obama_face_encoding = face_recognition.face_encodings(obama_image)

# Load a second sample picture and learn how to recognize it.
biden_image = face_recognition.load_image_file("images\\soukaina.jpg")
biden_face_encoding = face_recognition.face_encodings(biden_image)

# Create arrays of known face encodings and their names
known_face_encodings = [
    obama_face_encoding,
    biden_face_encoding
]
known_face_names = [
    "Ismail",
    "Soukaina"
]

# List
list = ['Ismail', 'Soukaina']

# Initialize some variables
face_locations = []
face_encodings = []
face_names = []
process_this_frame = True

while True:
    # Grab a single frame of video
    ret, frame = video_capture.read()

    # Resize frame of video to 1/4 size for faster face recognition processing
    small_frame = cv2.resize(frame, (0, 0), fx=0.25, fy=0.25)

    # Convert the image from BGR color (which OpenCV uses) to RGB color (which face_recognition uses)
    rgb_small_frame = small_frame[:, :, ::-1]

    # Only process every other frame of video to save time
    if process_this_frame:
        # Find all the faces and face encodings in the current frame of video
        face_locations = face_recognition.face_locations(rgb_small_frame)
        face_encodings = face_recognition.face_encodings(rgb_small_frame, face_locations)

        face_names = []
        for face_encoding in face_encodings:
            # See if the face is a match for the known face(s)
            matches = face_recognition.compare_faces(known_face_encodings, face_encoding)
            name = "Unknown"

            # # If a match was found in known_face_encodings, just use the first one.
            # if True in matches:
            #     first_match_index = matches.index(True)
            #     name = known_face_names[first_match_index]

            # Or instead, use the known face with the smallest distance to the new face
            face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
            best_match_index = np.argmin(face_distances)
            if matches[best_match_index]:
                name = known_face_names[best_match_index]
                list.remove(name)
                

            face_names.append(name)

    process_this_frame = not process_this_frame


    # Display the results
    for (top, right, bottom, left), name in zip(face_locations, face_names):
        # Scale back up face locations since the frame we detected in was scaled to 1/4 size
        top *= 4
        right *= 4
        bottom *= 4
        left *= 4

        # Draw a box around the face
        cv2.rectangle(frame, (left, top), (right, bottom), (0, 0, 255), 2)

        # Draw a label with a name below the face
        cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 0, 255), cv2.FILLED)
        font = cv2.FONT_HERSHEY_DUPLEX
        cv2.putText(frame, name, (left + 6, bottom - 6), font, 1.0, (255, 255, 255), 1)

    # Display the resulting image
    cv2.imshow('Video', frame)

    # Hit 'q' on the keyboard to quit!
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release handle to the webcam
video_capture.release()
cv2.destroyAllWindows()
